# %%
import pandas as pd
import plotly.graph_objects as go 
import numpy as np
from scipy.signal import butter, lfilter, freqz
from matplotlib import pyplot as plt

# %%
def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

# %%
def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
data = pd.read_csv('C://Users//Suhas Reddy//Downloads//Data//detailVolDownsampled.csv')
# Filter requirements.
order = 6
fs = 127.384       # sample rate, Hz
cutoff = 3.667  # desired cutoff frequency of the filter, Hz

# Get the filter coefficients so we can check its frequency response.
b, a = butter_lowpass(cutoff, fs, order)

# Plot the frequency response.
w, h = freqz(b, a, worN=8000)
plt.subplot(2, 1, 1)
plt.plot(0.5*fs*w/np.pi, np.abs(h), 'b')
plt.plot(cutoff, 0.5*np.sqrt(2), 'ko')
plt.axvline(cutoff, color='k')
plt.xlim(0, 0.5*fs)
plt.title("Lowpass Filter Frequency Response")
plt.xlabel('Frequency [Hz]')
plt.grid()

# %%
# Demonstrate the use of the filter.
# First make some data to be filtered.
T = 60.0             # seconds
n = int(T * fs)     # total number of samples
t = np.linspace(0, T, n, endpoint=False)
# "Noisy" data.  We want to recover the 1.2 Hz signal from this.
#data = np.sin(1.2*2*np.pi*t) + 1.5*np.cos(9*2*np.pi*t) \
        #+ 0.5*np.sin(12.0*2*np.pi*t)

# Filter the data, and plot both the original and filtered signals.
y = butter_lowpass_filter(data['Auxiliary channel TU1 U(V)'], cutoff, fs, order)

#plt.subplot(2, 1, 2)
plt.figure(figsize=(20,10))
plt.plot(t, data['Auxiliary channel TU1 U(V)'], 'b-', label='data')
plt.plot(t, y, 'g-', linewidth=2, label='filtered data')
plt.xlabel('Time [sec]')
plt.grid()
plt.legend()

plt.subplots_adjust(hspace=0.35)
plt.show()

# %% [markdown]
# The above plot explains how noise was filtered using butter_worth low_pass_filter
# x_axis of the plot consists of time duration in seconds
# y_axis of the plot consists of the signal values from auxillary channel.
# Blue line in legend means, original signal from the auxillary channel.
# Green lne in legend means, Noise filtered signal from the auxillary channel.
#
# As you can see from the above plot the low pass filter was able to filter the noise from orginal signal.
